# %%
import pandas as pd

# %%
import numpy as np

# %%
# Data ingestion step

df=pd.read_csv("data/gemstone.csv")

# %%
df.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
df.isnull().sum()
# Out:
# id         0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
# there is no misssing value in dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30002 entries, 0 to 30001
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       30002 non-null  int64
#  1   carat    30002 non-null  float64
#  2   cut      30002 non-null  object
#  3   color    30002 non-null  object
#  4   clarity  30002 non-null  object
#  5   depth    30002 non-null  float64
#  6   table    30002 non-null  float64
#  7   x        30002 non-null  float64
#  8   y        30002 non-null  float64
#  9   z        30002 non-null  float64
#  10  price    30002 non-null  int64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 2.5+ MB

# %%
df.head()
# Out:
#    id  carat        cut color clarity  depth  table     x     y     z  price
# 0   0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
# lets drop id column
df=df.drop(labels=['id'],axis=1)
df.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Segregate numrical and categorical column

num_col=df.columns[df.dtypes!='object']
cat_col=df.columns[df.dtypes=='object']

# %%
num_col
# Out:
# Index(['carat', 'depth', 'table', 'x', 'y', 'z', 'price'], dtype='object')

# %%
cat_col
# Out:
# Index(['cut', 'color', 'clarity'], dtype='object')

# %%
df.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
df[cat_col].describe()
# Out:
#           cut  color clarity
# count   30002  30002   30002
# unique      5      7       8
# top     Ideal      G     SI1
# freq    14398   6884    8192

# %%
df['cut'].value_counts()
# Out:
# cut
# Ideal        14398
# Premium       7757
# Very Good     5737
# Good          1784
# Fair           326
# Name: count, dtype: int64

# %%
df['color'].value_counts()
# Out:
# color
# G    6884
# E    5451
# F    5353
# H    4747
# D    3849
# I    2763
# J     955
# Name: count, dtype: int64

# %%
df['clarity'].value_counts()
# Out:
# clarity
# SI1     8192
# VS2     7477
# VS1     4731
# SI2     4706
# VVS2    2463
# VVS1    1673
# IF       675
# I1        85
# Name: count, dtype: int64

# %%
# plot graph for numerical columns

import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
x=1
for i in num_col:
    sns.histplot(data=df,x=i,kde=True,color='red')
    print('\n')
    plt.show()

# %%
# plot countplot for categorical columns

import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(6,8))
x=1
for i in cat_col:
    sns.countplot(data=df,x=i,color='red')
    print('\n')
    plt.show()

# %%
# correlation 
# sns.heatmap(df.corr(),annot=True)

# %%
# carat are huge corelated with x,y ,z columns ,so drop xyz

#df=df.drop(labels=['x','y','z'],axis=1)

# currently we not excute this

# %%
df.head()
# Out:
#    carat        cut color clarity  depth  table     x     y     z  price
# 0   1.52    Premium     F     VS2   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03  Very Good     J     SI2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70      Ideal     G     VS1   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32      Ideal     G     VS1   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70    Premium     G     VS2   62.6   59.0  7.65  7.61  4.77  14453

# %%
sns.pairplot(df)
# Out:
# c:\house_price_prediction\venv\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# craete mapper for cut clarity columns to do ordinal encoding

df['cut'].unique()
# Out:
# array(['Premium', 'Very Good', 'Ideal', 'Good', 'Fair'], dtype=object)

# %%
cut_map={'Fair':1,'Good':2,'Very Good':3,'Premium':4,'Ideal':5}

# %%
df['clarity'].unique()
# Out:
# array(['VS2', 'SI2', 'VS1', 'SI1', 'IF', 'VVS2', 'VVS1', 'I1'],
#       dtype=object)

# %%
clarity_map={'I1':1,'SI2':2,'SI1':3,'VS2':4,'VS1':5,'VVS2':6,'VVS1':7,'IF':8}

# %%
df['color'].unique()
# Out:
# array(['F', 'J', 'G', 'E', 'D', 'H', 'I'], dtype=object)

# %%
color_map={'D':1,'E':2,'F':3,'G':4,'H':5,'I':6,'J':7}

# %%
df['cut']=df['cut'].map(cut_map)
df['clarity']=df['clarity'].map(clarity_map)
df['color']=df['color'].map(color_map)

# %%
df.head()
# Out:
#    carat  cut  color  clarity  depth  table     x     y     z  price
# 0   1.52  NaN      3        4   62.2   58.0  7.27  7.33  4.55  13619
# 1   2.03  NaN      7        2   62.0   58.0  8.06  8.12  5.05  13387
# 2   0.70  NaN      4        5   61.2   57.0  5.69  5.73  3.50   2772
# 3   0.32  NaN      4        5   61.6   56.0  4.38  4.41  2.71    666
# 4   1.70  NaN      4        4   62.6   59.0  7.65  7.61  4.77  14453

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30002 entries, 0 to 30001
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    30002 non-null  float64
#  1   cut      0 non-null      float64
#  2   color    30002 non-null  int64
#  3   clarity  30002 non-null  int64
#  4   depth    30002 non-null  float64
#  5   table    30002 non-null  float64
#  6   x        30002 non-null  float64
#  7   y        30002 non-null  float64
#  8   z        30002 non-null  float64
#  9   price    30002 non-null  int64
# dtypes: float64(7), int64(3)
# memory usage: 2.3 MB
